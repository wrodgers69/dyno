# %%
import os
import keras
import keras.layers
from keras.models import *
from keras.utils import *
from PIL import Image
import numpy as np
from keras.preprocessing.image import *
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
model = load_model('/Users/leerodgers/Google Drive/codingprojects/dyno/trained_models/dyno_model_CNN_1')

# %%
img_path = '/Users/leerodgers/Google Drive/codingprojects/dyno/DjangoWebApp/djangoproject/dyno/utils/Good1.jpg'
img = image.load_img(img_path, target_size=(256, 256,1), grayscale = True)
display(img)
i_array = image.img_to_array(img)
x = np.expand_dims(i_array, axis=0)
x.shape
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x115856CC0>
# (1, 256, 256, 1)

# %%
prediction = model.predict_classes(x)
pp = model.predict_proba(x)
if prediction == 1:
    print('Prediction = Good, with %s probability' %(pp))
else:
    print('Bad')
# Out:
# Prediction = Good, with [[ 1.]] probability

# %%
def predict_from_path(img):
    img = image.load_img(img_path, target_size=(256, 256,1), grayscale = True)
    #display(img)
    i_array = image.img_to_array(img)
    x = np.expand_dims(i_array, axis=0)
    
    prediction = model.predict_classes(x)
    pp = model.predict_proba(x)
    
    if prediction == 1:
        return str('Prediction = Good with %s probability' % pp)
    else:
        return print('Bad')

# %%
def predict_from_file(file):
    
    img = Image.open(file).convert('LA')
    display(img)
    i_array = image.img_to_array(img)
    x = np.expand_dims(i_array, axis=0)
    
    prediction = model.predict_classes(x)
    pp = model.predict_proba(x)
    
    if prediction == 1:
        return str('Prediction = Good with %s probability' % pp)
    else:
        return print('Bad')

# %%
i = Image.open(img_path, target_size = (256,256))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-8f33d2e5d3d4> in <module>()
# ----> 1 i = Image.open(img_path, target_size = (256,256))
#
# TypeError: open() got an unexpected keyword argument 'target_size'

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1333x1220 at 0x116C55978>

# %%
file = 'pic.jpg'
save_path = str("/Users/leerodgers/Google Drive/codingprojects/dyno/DjangoWebApp/djangoproject/dyno/images/%s" %file)
img.save('/Users/leerodgers/Google Drive/codingprojects/dyno/DjangoWebApp/djangoproject/dyno/images/photo1.jpg', format = 'JPEG')

# %%
save_path
# Out:
# '/Users/leerodgers/Google Drive/codingprojects/dyno/DjangoWebApp/djangoproject/dyno/images/pic.jpg'
